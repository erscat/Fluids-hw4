# %% [markdown]
# Implementing sound waves in uniform density 1D gas with no body force

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Nsteps = 1000
A = 0.5 # Perturbation amplitude
d = 0.01 # Perturbation width
N = 500 # Leftmost cell is 0, rightmost cell is N
Q = 0.95
Cs = 0.5
X = np.linspace(0, 1, N)
dx = X[1] - X[0]
dt = Q*dx/Cs

gaussian = A*np.exp(-(X-0.5)**2/ (2*d**2))
density = np.ones(X.shape)* (1+gaussian)
momentum = np.zeros(X.shape)

# %matplotlib notebook
fig, axs = plt.subplots(2)
plt.ion()
fig.show()
fig.canvas.draw()

for i in range(Nsteps):
    # Update without source
    velocity_face = 1/2 * (momentum[:-1]/density[:-1] + momentum[1:]/density[1:])
    flux_dens_face = []
    flux_mom_face = []
    
    for i, veloc in enumerate(velocity_face):
        if veloc < 0:
            flux_dens_face.append(veloc * density[i+1])
            flux_mom_face.append(veloc * momentum[i+1])
        else:
            flux_dens_face.append(veloc * density[i])
            flux_mom_face.append(veloc * momentum[i])
    
    # Update including boundary conditions
    flux_dens_face = np.array(flux_dens_face)
    density[1:-1] -= dt/dx * (flux_dens_face[1:] - flux_dens_face[:-1])
    density[0] -= dt/dx * flux_dens_face[0]
    density[-1] += dt/dx * flux_dens_face[-1]
    flux_mom_face = np.array(flux_mom_face)
    momentum[1:-1] -= dt/dx * (flux_mom_face[1:] - flux_mom_face[:-1])
    momentum[0] -= dt/dx * flux_mom_face[0]
    momentum[-1] += dt/dx * flux_mom_face[-1]

    
    # Update with source
    velocity_face = 1/2 * (momentum[:-1]/density[:-1] + momentum[1:]/density[1:])
    flux_dens_face = []
    flux_mom_face = []
    
    for i, veloc in enumerate(velocity_face):
        if veloc < 0:
            flux_dens_face.append(veloc * density[i+1])
            flux_mom_face.append(veloc * momentum[i+1])
        else:
            flux_dens_face.append(veloc * density[i])
            flux_mom_face.append(veloc * momentum[i])
            
    momentum[1:-1] -= dt/dx * Cs**2 / 2 * (density[2:] - density[:-2])
    
    # Boundary conditions
    momentum[0] -= dt/dx/2 * (density[1] - density[0])
    momentum[-1] -= dt/dx/2 * (density[-1] - density[-2])

    mach = [speed / Cs for speed in velocity_face]
    mach = mach + [0]
    axs[0].clear()
    axs[1].clear()
    axs[0].set_xlim(0, 1)
    axs[0].set_ylim(1, 1+2*A)
    axs[0].plot(X, density)
    axs[1].plot(X, mach)
    fig.canvas.draw()
    plt.pause(0.001)
# Out:
# <img src="data:image/png;base64,..." width="639.75">
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:57: RuntimeWarning: overflow encountered in double_scalars
#   flux_mom_face.append(veloc * momentum[i])
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:54: RuntimeWarning: overflow encountered in double_scalars
#   flux_mom_face.append(veloc * momentum[i+1])
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:33: RuntimeWarning: overflow encountered in double_scalars
#   flux_mom_face.append(veloc * momentum[i])
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:30: RuntimeWarning: overflow encountered in double_scalars
#   flux_mom_face.append(veloc * momentum[i+1])
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:41: RuntimeWarning: invalid value encountered in subtract
#   momentum[1:-1] -= dt/dx * (flux_mom_face[1:] - flux_mom_face[:-1])
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:47: RuntimeWarning: invalid value encountered in divide
#   velocity_face = 1/2 * (momentum[:-1]/density[:-1] + momentum[1:]/density[1:])
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:59: RuntimeWarning: invalid value encountered in subtract
#   momentum[1:-1] -= dt/dx * Cs**2 / 2 * (density[2:] - density[:-2])
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:23: RuntimeWarning: invalid value encountered in divide
#   velocity_face = 1/2 * (momentum[:-1]/density[:-1] + momentum[1:]/density[1:])
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:53: RuntimeWarning: overflow encountered in double_scalars
#   flux_dens_face.append(veloc * density[i+1])
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:56: RuntimeWarning: overflow encountered in double_scalars
#   flux_dens_face.append(veloc * density[i])
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:23: RuntimeWarning: invalid value encountered in add
#   velocity_face = 1/2 * (momentum[:-1]/density[:-1] + momentum[1:]/density[1:])
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:29: RuntimeWarning: overflow encountered in double_scalars
#   flux_dens_face.append(veloc * density[i+1])
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:32: RuntimeWarning: overflow encountered in double_scalars
#   flux_dens_face.append(veloc * density[i])
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:41: RuntimeWarning: overflow encountered in multiply
#   momentum[1:-1] -= dt/dx * (flux_mom_face[1:] - flux_mom_face[:-1])
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:37: RuntimeWarning: invalid value encountered in subtract
#   density[1:-1] -= dt/dx * (flux_dens_face[1:] - flux_dens_face[:-1])
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:37: RuntimeWarning: overflow encountered in multiply
#   density[1:-1] -= dt/dx * (flux_dens_face[1:] - flux_dens_face[:-1])
# C:\Users\Walle\AppData\Local\Temp\ipykernel_19964\427401379.py:37: RuntimeWarning: overflow encountered in multiply
#   density[1:-1] -= dt/dx * (flux_dens_face[1:] - flux_dens_face[:-1])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 74
#      72 axs[1].plot(X, mach)
#      73 fig.canvas.draw()
# ---> 74 plt.pause(0.001)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:569, in pause(interval)
#     567         canvas.draw_idle()
#     568     show(block=False)
# --> 569     canvas.start_event_loop(interval)
#     570 else:
#     571     time.sleep(interval)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\backend_bases.py:2519, in FigureCanvasBase.start_event_loop(self, timeout)
#    2517 while self._looping and counter * timestep < timeout:
#    2518     self.flush_events()
# -> 2519     time.sleep(timestep)
#    2520     counter += 1
#
# KeyboardInterrupt:
